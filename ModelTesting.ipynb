# %% [markdown]
# # Model Testing

# %% [markdown]
# ## Import and Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
# Import amphibian data
amphibian_df = pd.read_csv("/Users/ljw/Projects/ModelsFromScratch/DataSources/Amphibians/dataset.csv", delimiter=";", skiprows=1)
amphibian_df.head()
# Out:
#    ID Motorway   SR  NR  TR  VR  SUR1  SUR2  SUR3  UR  ...  BR  MR  CR  \
# 0   1       A1  600   1   1   4     6     2    10   0  ...   0   0   1
# 1   2       A1  700   1   5   1    10     6    10   3  ...   1   0   1
# 2   3       A1  200   1   5   1    10     6    10   3  ...   1   0   1
# 3   4       A1  300   1   5   0     6    10     2   3  ...   0   0   1
# 4   5       A1  600   2   1   4    10     2     6   0  ...   5   0   1
#
#    Green frogs  Brown frogs  Common toad  Fire-bellied toad  Tree frog  \
# 0            0            0            0                  0          0
# 1            0            1            1                  0          0
# 2            0            1            1                  0          0
# 3            0            0            1                  0          0
# 4            0            1            1                  1          0
#
#    Common newt  Great crested newt
# 0            0                   0
# 1            1                   0
# ...

# %%
# Convert frog flags to boolean

# %%
amphibian_df["amph_present"] = \
    amphibian_df["Green frogs"] | \
    amphibian_df["Brown frogs"] | \
    amphibian_df["Common toad"] | \
    amphibian_df["Fire-bellied toad"] | \
    amphibian_df["Tree frog"] | \
    amphibian_df["Common newt"] | \
    amphibian_df["Great crested newt"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/b1/rrj56xwx47qcmjwx198bfqsc0000gn/T/ipykernel_54142/859441492.py in ?()
#       1 amphibian_df["amph_present"] = \
# ----> 2     amphibian_df["Green frogs"]==1 | \
#       3     amphibian_df["Brown frogs"]==1 | \
#       4     amphibian_df["Common toad"]==1 | \
#       5     amphibian_df["Fire-bellied toad"]==1 | \
#
# ~/Projects/ModelsFromScratch/.models_venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
